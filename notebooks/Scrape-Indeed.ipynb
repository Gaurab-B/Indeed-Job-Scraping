faq" class="mosaic-provider-jobcards-1f8zkg3 e19afand0">questions &amp; answers about Procter &amp; Gamble</a></span></li></ul></div></div></div></div></div><div class="ctaContainer"></div><div aria-live="polite"></div></div></div></div></div></div><span aria-live="polite" class="visually-hidden css-10pe3me eu4oa1w0"></span><!--/$--></li><li class="css-5lfssm eu4oa1w0"><!--$--><div class="cardOutline tapItem dd-privacy-allow result job_7b816420a261a30b resultWithShelf sponTapItem desktop hasSection hasSection-default nonRecommendation-section css-yria2i eu4oa1w0"><div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div data-testid="slider_item" class="slider_item css-mk9n32 eu4oa1w0"><div class="job_seen_beacon"><table class="big6_visualChanges css-1v79ar eu4oa1w0" cellpadding="0" cellspacing="0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><div class="css-dekpa e37uo190"><h2 class="jobTitle css-198pbd eu4oa1w0" tabindex="-1"><a id="job_7b816420a261a30b" data-mobtk="1i257d8c4ikf988i" data-jk="7b816420a261a30b" data-hiring-event="false" data-hide-spinner="true" role="button" aria-label="full details of Assistant Vice President/Vice President of Advanced Analytics" class="jcs-JobTitle css-jspxzf eu4oa1w0" href="/rc/clk?jk=7b816420a261a30b&amp;bb=yvdDBZNRWaEitJWvxLeNWjEENLu6gtwGKFLVysxV2TDcOGU-XYXZfcwDEwCDsv0uySRtbhQTEwz6ukknlcyoVs_pmohgMOvo-7wjXNiLnFZWjBCYaFnRxg%3D%3D&amp;xkcb=SoDt67M3-FG61NwiCJ0FbzkdCdPP&amp;fccid=11e7471668f88afd&amp;vjs=3"><span title="Assistant Vice President/Vice President of Advanced Analytics" id="jobTitle-7b816420a261a30b">Assistant Vice President/Vice President of Advanced Analytics</span></a></h2><div class="css-1hlnck6 e37uo190"></div></div><div class="company_location css-17fky0v e37uo190"><div data-testid="timing-attribute"><div class="css-1qv0295 e37uo190"><span data-testid="company-name" class="css-63koeb eu4oa1w0">Great American Insurance Company</span></div><div data-testid="text-location" class="css-1p0sjhy eu4oa1w0">Cincinnati, OH 45202<!-- -->&nbsp;<div class="css-132mwr2 eu4oa1w0">(<!-- -->Central Business District area<!-- -->)</div></div></div></div><div class="jobMetaDataGroup css-pj786l eu4oa1w0"><div class="heading6 tapItem-gutter metadataContainer css-z5ecg7 eu4oa1w0"><div class="mosaic-provider-jobcards-1sqf5in e1xnxm2i0"><div class="mosaic-provider-jobcards-g6kqeb ecydgvn0"><div class="mosaic-provider-jobcards-tvvxwd ecydgvn1">Pay information not provided</div></div></div><div class="metadata css-5zy3wz eu4oa1w0"><div data-testid="attribute_snippet_testid" class="css-1cvvo1b eu4oa1w0">Full-time</div></div></div><div class="heading6 error-text tapItem-gutter"></div></div></td><td class="css-biqn32 eu4oa1w0"><button aria-haspopup="true" title="More" aria-label="Job actions for Assistant Vice President/Vice President of Advanced Analytics is collapsed" class="e8ju0x51 mosaic-provider-jobcards-1kkwgax ex6cvhv1" id="jobActionButton-7b816420a261a30b" type="button" data-reach-menu-button=""><svg xmlns="http://www.w3.org/2000/svg" focusable="false" role="img" fill="currentColor" viewBox="0 0 24 24" aria-hidden="true" class="mosaic-provider-jobcards-1luvpuv eac13zx0"><path d="M12 7c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 3c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 7c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></button></td></tr></tbody></table><div role="presentation" class="css-1u8dvic eu4oa1w0"><div class="css-10vq04l eu4oa1w0"><span class="css-wftrf9 eu4oa1w0"><span class="iaIcon css-pu2c8l eu4oa1w0"><svg xmlns="http://www.w3.org/2000/svg" focusable="false" role="img" fill="currentColor" viewBox="0 0 24 24" aria-hidden="true" class="mosaic-provider-jobcards-1tvjh98 eac13zx0"><path d="M2.344 4.018a.25.25 0 00-.33.31l1.897 5.895a.5.5 0 00.371.335l7.72 1.44-7.72 1.44a.5.5 0 00-.371.335l-1.898 5.896a.25.25 0 00.33.31l19.494-7.749a.25.25 0 000-.464L2.344 4.018z"></path></svg></span><span class="ialbl iaTextBlack css-130a5xa eu4oa1w0" data-testid="indeedApply">Easily apply</span></span></div><div class="underShelfFooter"><div class="heading6 tapItem-gutter css-1rgici5 eu4oa1w0"><div class="css-9446fg eu4oa1w0"><ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;"> <li>Spearhead data science initiatives incorporating <b>artificial</b> <b>intelligence</b> and machine learning to optimize business processes and product offerings.</li></ul></div><span data-testid="myJobsStateDate" class="css-qvloho eu4oa1w0"><span class="css-10pe3me eu4oa1w0">Posted</span>Posted 30+ days ago</span><span class="css-opxvw7 eu4oa1w0">·</span><button type="button" data-testid="more_links_button" class="sl resultLink css-ff8z8x eu4oa1w0" aria-expanded="false">More...</button></div><div class="css-6iwpn6 eu4oa1w0"><div class="result-tab css-9pzb1s eu4oa1w0"><div data-testid="more_links" class="css-ldptw eu4oa1w0"><button type="button" title="Close" aria-label="Close" class="css-1dvqyzs eu4oa1w0"></button><ul><li><span class="mat">View all <a href="/q-great-american-insurance-company-l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">Great American Insurance Company jobs in Cincinnati, OH</a> - <a href="/l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">Cincinnati jobs</a> - <a href="/q-assistant-vice-president-l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">Assistant Vice President jobs in Cincinnati, OH</a></span></li><li><span class="mat">Salary Search: <a href="/career/assistant-vice-president/salaries/45202--OH?campaignid=serp-more&amp;fromjk=7b816420a261a30b&amp;from=serp-more" class="mosaic-provider-jobcards-1f8zkg3 e19afand0">Assistant Vice President/Vice President of Advanced Analytics salaries in Cincinnati, OH</a></span></li><li><span class="mat">See popular <a href="/cmp/Great-American-Insurance-Group/faq" class="mosaic-provider-jobcards-1f8zkg3 e19afand0">questions &amp; answers about Great American Insurance Company</a></span></li></ul></div></div></div></div></div><div class="ctaContainer"></div><div aria-live="polite"></div></div></div></div></div></div><span aria-live="polite" class="visually-hidden css-10pe3me eu4oa1w0"></span><!--/$--></li><li class="css-5lfssm eu4oa1w0"><div id="mosaic-afterFifteenthJobResult" class="mosaic mosaic-empty-zone nonJobContent-desktop" data-testid="mosaicZone_afterFifteenthJobResult"></div></li></ul><div id="toast" aria-live="polite"></div><script>window.JCS_onClk = function Ce(e){e.preventDefault(),e.stopPropagation();for(var t=e.target,r=!1,n=!1;t;){if(t.className?.indexOf)if(t.className.indexOf("bookmark ")>-1)r=!0;else if(t.className.indexOf("dislike-tap-target ")>-1)n=!0;else if(t.className.indexOf("result ")>-1){r?window.jcsSavedJobs.indexOf(t.id)<0&&window.jcsSavedJobs.push(t.id):n?window.jcsDislikedJobs.indexOf(t.id)<0&&window.jcsDislikedJobs.push(t.id):window.jcsClickedJob=t.id;break}t=t.parentNode}};(function(){if(!window.jcsSavedJobs){var e=document.getElementById("mosaic-provider-jobcards");window.jcsSavedJobs=[],window.jcsDislikedJobs=[],window.jcsClickedJob=null,e&&(e.addEventListener("click",window.JCS_onClk),window.removeJcsOnClickFn=function(){e&&e.removeEventListener("click",window.JCS_onClk)})}})();</script></div></div> '

# %%
data = r'<div id="mosaic-jobResults" class="mosaic-zone"><div id="mosaic-provider-jobcards" class="mosaic mosaic-provider-jobcards mosaic-provider-hydrated"><ul class="css-zu9cdh eu4oa1w0"><li class="css-5lfssm eu4oa1w0"><!--$--><div class="cardOutline tapItem dd-privacy-allow result job
span></a></h2><div class="css-1hlnck6 e37uo190"></div></div><div class="company_location css-17fky0v e37uo190"><div data-testid="timing-attribute"><div class="css-1qv0295 e37uo190"><span data-testid="company-name" class="css-63koeb eu4oa1w0">Bon Secours Mercy Health</span></div><div data-testid="text-location" class="css-1p0sjhy eu4oa1w0">Cincinnati, OH 45237<!-- -->&nbsp;<div class="css-132mwr2 eu4oa1w0">(<!-- -->Roselawn area<!-- -->)</div></div></div></div><div class="jobMetaDataGroup css-pj786l eu4oa1w0"><div class="heading6 tapItem-gutter metadataContainer css-z5ecg7 eu4oa1w0"><div class="mosaic-provider-jobcards-1sqf5in e1xnxm2i0"><div class="mosaic-provider-jobcards-g6kqeb ecydgvn0"><div class="mosaic-provider-jobcards-tvvxwd ecydgvn1">Pay information not provided</div></div></div></div><div class="heading6 error-text tapItem-gutter"></div></div></td><td class="css-biqn32 eu4oa1w0"><button aria-haspopup="true" title="More" aria-label="Job actions for Privacy Director is collapsed" class="e8ju0x51 mosaic-provider-jobcards-1kkwgax ex6cvhv1" id="jobActionButton-2e607455fa0f40c9" type="button" data-reach-menu-button=""><svg xmlns="http://www.w3.org/2000/svg" focusable="false" role="img" fill="currentColor" viewBox="0 0 24 24" aria-hidden="true" class="mosaic-provider-jobcards-1luvpuv eac13zx0"><path d="M12 7c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 3c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 7c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></button></td></tr></tbody></table><div role="presentation" class="css-1u8dvic eu4oa1w0"><div class="css-10vq04l eu4oa1w0"><span class="css-wftrf9 eu4oa1w0"><span class="iaIcon css-pu2c8l eu4oa1w0"><svg xmlns="http://www.w3.org/2000/svg" focusable="false" role="img" fill="currentColor" viewBox="0 0 24 24" aria-hidden="true" class="mosaic-provider-jobcards-1tvjh98 eac13zx0"><path d="M2.344 4.018a.25.25 0 00-.33.31l1.897 5.895a.5.5 0 00.371.335l7.72 1.44-7.72 1.44a.5.5 0 00-.371.335l-1.898 5.896a.25.25 0 00.33.31l19.494-7.749a.25.25 0 000-.464L2.344 4.018z"></path></svg></span><span class="ialbl iaTextBlack css-130a5xa eu4oa1w0" data-testid="indeedApply">Easily apply</span></span></div><div class="underShelfFooter"><div class="heading6 tapItem-gutter css-1rgici5 eu4oa1w0"><div class="css-9446fg eu4oa1w0"><ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;"> <li>We are looking for a candidate who has researched regulatory law, has expert knowledge in HIPAA, has at least 5-7 years of experience in healthcare law …</li></ul></div><span data-testid="myJobsStateDate" class="css-qvloho eu4oa1w0"><span class="css-10pe3me eu4oa1w0">Posted</span>Posted 30 days ago</span><span class="css-opxvw7 eu4oa1w0">·</span><button type="button" data-testid="more_links_button" class="sl resultLink css-ff8z8x eu4oa1w0" aria-expanded="false">More...</button></div><div class="css-6iwpn6 eu4oa1w0"><div class="result-tab css-9pzb1s eu4oa1w0"><div data-testid="more_links" class="css-ldptw eu4oa1w0"><button type="button" title="Close" aria-label="Close" class="css-1dvqyzs eu4oa1w0"></button><ul><li><span class="mat">View all <a href="/q-bon-secours-mercy-health-l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">Bon Secours Mercy Health jobs in Cincinnati, OH</a> - <a href="/l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">Cincinnati jobs</a> - <a href="/q-director-l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">Director jobs in Cincinnati, OH</a></span></li><li><span class="mat">Salary Search: <a href="/career/director/salaries/45237--OH?campaignid=serp-more&amp;fromjk=2e607455fa0f40c9&amp;from=serp-more" class="mosaic-provider-jobcards-1f8zkg3 e19afand0">Privacy Director salaries in Cincinnati, OH</a></span></li><li><span class="mat">See popular <a href="/cmp/Bon-Secours-Mercy-Health/faq" class="mosaic-provider-jobcards-1f8zkg3 e19afand0">questions &amp; answers about Bon Secours Mercy Health</a></span></li></ul></div></div></div></div></div><div class="ctaContainer"></div><div aria-live="polite"></div></div></div></div></div></div><span aria-live="polite" class="visually-hidden css-10pe3me eu4oa1w0"></span><!--/$--></li><li class="css-5lfssm eu4oa1w0"><!--$--><div class="cardOutline tapItem dd-privacy-allow result job_c1f7583df0a1a9df resultWithShelf sponTapItem desktop hasSection hasSection-default nonRecommendation-section css-yria2i eu4oa1w0"><div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div data-testid="slider_item" class="slider_item css-mk9n32 eu4oa1w0"><div class="job_seen_beacon"><table class="big6_visualChanges css-1v79ar eu4oa1w0" cellpadding="0" cellspacing="0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><div class="css-dekpa e37uo190"><h2 class="jobTitle css-198pbd eu4oa1w0" tabindex="-1"><a id="job_c1f7583df0a1a9df" data-mobtk="1i25ojn08i3qf800" data-jk="c1f7583df0a1a9df" data-hiring-event="false" data-hide-spinner="true" role="button" aria-label="full details of SAP BTP Consultant" class="jcs-JobTitle css-jspxzf eu4oa1w0" href="/rc/clk?jk=c1f7583df0a1a9df&amp;bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&amp;xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&amp;fccid=a4e4e2eaf26690c9&amp;vjs=3"><span title="SAP BTP Consultant" id="jobTitle-c1f7583df0a1a9df">SAP BTP Consultant</span></a></h2><div class="css-1hlnck6 e37uo190"></div></div><div class="company_location css-17fky0v e37uo190"><div data-testid="timing-attribute"><div class="css-1qv0295 e37uo190"><span data-testid="company-name" class="css-63koeb eu4oa1w0">Accenture</span></div><div data-testid="text-location" class="css-1p0sjhy eu4oa1w0">Cincinnati, OH 45202<!-- -->&nbsp;<div class="css-132mwr2 eu4oa1w0">(<!-- -->Central Business District area<!-- -->)</div></div></div></div><div class="jobMetaDataGroup css-pj786l eu4oa1w0"><div class="mosaic-provider-jobcards-5q1wun e1xnxm2i0"><div class="mosaic-provider-jobcards-g6kqeb ecydgvn0"><div class="mosaic-provider-jobcards-tvvxwd ecydgvn1"><svg xmlns="http://www.w3.org/2000/svg" focusable="false" role="img" fill="currentColor" viewBox="0 0 24 24" aria-hidden="true" class="mosaic-provider-jobcards-108cfha eac13zx0"><path fill-rule="evenodd" d="M13.003 2.262c0-.262-.342-.363-.484-.142L5.084 13.69c-.224.35.027.81.442.81h5.479v7.237c0 .262.342.362.484.142l7.435-11.57a.525.525 0 00-.442-.81h-5.48V2.262z" clip-rule="evenodd"></path></svg></div><div class="mosaic-provider-jobcards-tvvxwd ecydgvn1">Typically responds within 3 days</div></div></div><div class="heading6 tapItem-gutter metadataContainer css-z5ecg7 eu4oa1w0"><div class="mosaic-provider-jobcards-1sqf5in e1xnxm2i0"><div class="mosaic-provider-jobcards-g6kqeb ecydgvn0"><div class="mosaic-provider-jobcards-tvvxwd ecydgvn1">Pay information not provided</div></div></div><div class="metadata css-5zy3wz eu4oa1w0"><div data-testid="attribute_snippet_testid" class="css-1cvvo1b eu4oa1w0">Full-time</div></div></div><div class="heading6 error-text tapItem-gutter"></div></div></td><td class="css-biqn32 eu4oa1w0"><button aria-haspopup="true" title="More" aria-label="Job actions for SAP BTP Consultant is collapsed" class="e8ju0x51 mosaic-provider-jobcards-1kkwgax ex6cvhv1" id="jobActionButton-c1f7583df0a1a9df" type="button" data-reach-menu-button=""><svg xmlns="http://www.w3.org/2000/svg" focusable="false" role="img" fill="currentColor" viewBox="0 0 24 24" aria-hidden="true" class="mosaic-provider-jobcards-1luvpuv eac13zx0"><path d="M12 7c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 3c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 7c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></button></td></tr></tbody></table><div role="presentation" class="css-1u8dvic eu4oa1w0"><div class="underShelfFooter"><div class="heading6 tapItem-gutter css-1rgici5 eu4oa1w0"><div class="css-9446fg eu4oa1w0"><ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;"> <li>Accenture’s SAP practice, and we bring the New to life using design thinking, agile development methodologies, and the latest smart tech for SAP when it comes…</li></ul></div><span data-testid="myJobsStateDate" class="css-qvloho eu4oa1w0"><span class="css-10pe3me eu4oa1w0">Posted</span>Posted 29 days ago</span><span class="css-opxvw7 eu4oa1w0">·</span><button type="button" data-testid="more_links_button" class="sl resultLink css-ff8z8x eu4oa1w0" aria-expanded="false">More...</button></div><div class="css-6iwpn6 eu4oa1w0"><div class="result-tab css-9pzb1s eu4oa1w0"><div data-testid="more_links" class="css-ldptw eu4oa1w0"><button type="button" title="Close" aria-label="Close" class="css-1dvqyzs eu4oa1w0"></button><ul><li><span class="mat">View all <a href="/q-accenture-l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">Accenture jobs in Cincinnati, OH</a> - <a href="/l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">Cincinnati jobs</a> - <a href="/q-sap-consultant-l-cincinnati,-oh-jobs.html" class="css-1f8zkg3 e19afand0">SAP Consultant jobs in Cincinnati, OH</a></span></li><li><span class="mat">Salary Search: <a href="/career/sap-consultant/salaries/Cincinnati--OH?campaignid=serp-more&amp;fromjk=c1f7583df0a1a9df&amp;from=serp-more" class="mosaic-provider-jobcards-1f8zkg3 e19afand0">SAP BTP Consultant salaries in Cincinnati, OH</a></span></li><li><span class="mat">See popular <a href="/cmp/Accenture/faq" class="mosaic-provider-jobcards-1f8zkg3 e19afand0">questions &amp; answers about Accenture</a></span></li></ul></div></div></div></div></div><div class="ctaContainer"></div><div aria-live="polite"></div></div></div></div></div></div><span aria-live="polite" class="visually-hidden css-10pe3me eu4oa1w0"></span><!--/$--></li><li class="css-5lfssm eu4oa1w0"><div id="mosaic-afterFifteenthJobResult" class="mosaic mosaic-empty-zone nonJobContent-desktop" data-testid="mosaicZone_afterFifteenthJobResult"></div></li></ul><div id="toast" aria-live="polite"></div><script>window.JCS_onClk = function Ce(e){e.preventDefault(),e.stopPropagation();for(var t=e.target,r=!1,n=!1;t;){if(t.className?.indexOf)if(t.className.indexOf("bookmark ")>-1)r=!0;else if(t.className.indexOf("dislike-tap-target ")>-1)n=!0;else if(t.className.indexOf("result ")>-1){r?window.jcsSavedJobs.indexOf(t.id)<0&&window.jcsSavedJobs.push(t.id):n?window.jcsDislikedJobs.indexOf(t.id)<0&&window.jcsDislikedJobs.push(t.id):window.jcsClickedJob=t.id;break}t=t.parentNode}};(function(){if(!window.jcsSavedJobs){var e=document.getElementById("mosaic-provider-jobcards");window.jcsSavedJobs=[],window.jcsDislikedJobs=[],window.jcsClickedJob=null,e&&(e.addEventListener("click",window.JCS_onClk),window.removeJcsOnClickFn=function(){e&&e.removeEventListener("click",window.JCS_onClk)})}})();</script></div></div> '

# %%
soup = BeautifulSoup(data, 'html.parser')
everything = soup.find_all('div', class_='job_seen_beacon')
everything #This contains 15 sliders per indeed page!
# Out:
# [<div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><div class="css-dekpa e37uo190"><h2 class="jobTitle jobTitle-newJob css-198pbd eu4oa1w0" tabindex="-1"><a aria-label="full details of MRI Technologist" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-ci="415066386" data-empn="5748677195806788" data-hide-spinner="true" data-hiring-event="false" data-jk="0c88da090953afe8" data-mobtk="1i25ojn08i3qf800" href="https://www.indeed.com/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BKkHZu3wF05EeDimN_p6sYpKCMArvwa95YdH7UpkaBCkugsAQrRfiKpbMgfSGYRE77SuLYNqkqqjWJjmXwmj_rqGDowD0Dnx9sDq2Ts73d2Lh49wOJmSnWbwPo0kyelbYaY5lH0G9AKbVYjPRmeWDiNv_IenvXarck4OfYeluc3WiC1nsGyu9GmpDBlg6i2SjaAOKDn2kML2QeLN1MHVY3zNZCWZvc1OGAZSzM8UwTvhSb7My4ZcuS8oTuTWDSjZo_KothvEquR1Hc3GkYN2XELcSbOxsYMATBK1q_ZVQUElnn2XOO-aX4eavXiVy_d5w41TSgmR584v-OrWI3f3446_DBiAs0G2A_v_QmfGO2NAaSQwifvuGAVVizMucFVmZKTr6yCP
# ...

# %%
job_titles = []
company = []
location = []
salary = []
job_types = []
for jobs in everything:
    h2_elements1 = jobs.find_all('h2', class_='jobTitle css-198pbd eu4oa1w0') #get the title
    h2_elements2 = jobs.find_all('h2', class_='jobTitle jobTitle-newJob css-198pbd eu4oa1w0')
    h2_elements = h2_elements1 + h2_elements2
    for h2 in h2_elements:
        job_name_span = h2.find('span', id=lambda x: x and x.startswith('jobTitle-'))
        if job_name_span:
            job_name = job_name_span.get('title', job_name_span.text)
            job_titles.append(job_name)  #append the title

    div_elements = jobs.select('div.company_location')
    for div in div_elements:
        company_div = div.find('span', {'data-testid': 'company-name'}) #company
        location_div = div.find('div', {'data-testid': 'text-location'}) #location
        if company_div:
            company.append(company_div.text)    
        if location_div:
            location.append(location_div.text) 
            #now we get the salary and the type of the job 
    pay_elements = jobs.find_all('div', class_='jobMetaDataGroup css-pj786l eu4oa1w0') #get payment&job-type details
    for pay in pay_elements:
        pay_div = pay.find('div', class_='salary-snippet-container') 
        type_div = pay.find('div', class_='metadata css-5zy3wz eu4oa1w0')
        if pay_div:
            salary.append(pay_div.text.strip())
        else:
            salary.append('Not Provided') #salary
        if type_div:
            job_types.append(type_div.find('div', {'data-testid': 'attribute_snippet_testid'}).text.strip())
        else:
            job_types.append('Not Provided')

# %%
all_descriptions = []
all_dates = []
for description in everything:
        descr = description.find('div', class_='css-1u8dvic eu4oa1w0') 
        if descr:
            output = descr.find('ul').text.strip()
            all_descriptions.append(output)
        # Find the date element
        date_element = description.find('span', class_='css-qvloho eu4oa1w0')
        if date_element:
        # Extract and append the date text to the list
            date_text = date_element.text.strip()
            all_dates.append(date_text)
all_descriptions
# Out:
# ['This group receives on average 30 patients per day and sees a lot of brain and spine cases (mainly outpatient).ARRT or NMTCB, BLS/CPR.',
#  'Integrate artificial intelligence to support a chatbot feature to interact with the LLM.You will collaborate closely with cross-functional teams, including…',
#  'We are Technology Strategy and Advisory and we design and execute industry-relevant reinventions that allow organizations to realize exceptional business value…',
#  'You will leverage your expertise in data, AI, and reinventing customer experiences to shape end-to-end digital transformations, unlocking the potential of…',
#  'Lead client engagements focused on digital transformation, operational excellence, and sustainability initiatives.',
#  'Define use cases and business cases for applying modern technology in the PV space, including digital and applied intelligence.',
# ...

# %%
all_links = []
for link in everything:
    h2_elements1 = jobs.find_all('h2', class_='jobTitle css-198pbd eu4oa1w0') #get the title
    h2_elements2 = jobs.find_all('h2', class_='jobTitle jobTitle-newJob css-198pbd eu4oa1w0')
    h2_elements = h2_elements1 + h2_elements2
    # Loop through each h2 element
    for h2 in h2_elements:
        # Find the anchor tag (a) within the h2 element
        a_tag = h2.find('a')
        if a_tag:
            # Extract the 'href' attribute value from the anchor tag
            job_link = a_tag.get('href', '')
            all_links.append(job_link)

# %%
all_links
# Out:
# ['/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  '/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  '/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  '/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
# ...

# %%
all_dates
# Out:
# ['PostedPosted 1 day ago',
#  'PostedPosted 30+ days ago',
#  'PostedPosted 23 days ago',
#  'PostedPosted 16 days ago',
#  'PostedPosted 30+ days ago',
#  'PostedPosted 5 days ago',
#  'PostedPosted 30+ days ago',
#  'PostedPosted 19 days ago',
#  'PostedPosted 4 days ago',
#  'PostedPosted 9 days ago',
#  'PostedPosted 30+ days ago',
#  'EmployerActive 13 days ago',
#  'PostedPosted 4 days ago',
#  'PostedPosted 30 days ago',
#  'PostedPosted 29 days ago']

# %%
job_titles
# Out:
# ['MRI Technologist',
#  'Experienced Scientist - Large Language Modeling',
#  'Technology Strategy & Advisory Consultant or Manager - Infrastructure Optimization and Modernization',
#  'Google Integrated Practice Leads',
#  'Natural Resources Industry, Consulting Associate Director',
#  'Life Sciences R&D Consulting Drug Safety Senior Manager',
#  'Emerging Technology Product Manager',
#  'Chief of Staff - Director, Strategy & Data Advanced Analytics (P2494)',
#  'Executive Office Administrator',
#  'Manager, Category Leadership, M&B',
#  'EPA Postdoctoral Fellowship on Machine Learning Applications for Lead Service Line Identification',
#  'Consulting Account Partner (Aerospace)',
#  'Fair and Responsible Banking Analytics Director',
#  'Privacy Director',
#  'SAP BTP Consultant']

# %%
company
# Out:
# ['Insight Global',
#  'Medpace, Inc.',
#  'Accenture',
#  'Accenture',
#  'Accenture',
#  'Accenture',
#  'Great American Insurance Company',
#  '84.51°',
#  'NaviStone',
#  'Campbell Soup Company',
#  'U.S. Environmental Protection Agency (EPA)',
#  'NLB Technology Services',
#  'U.S. Bank National Association',
#  'Bon Secours Mercy Health',
#  'Accenture']

# %%
location
# Out:
# ['Cincinnati, OH 45220\xa0(CUF area)',
#  'Hybrid work in Cincinnati, OH 45227',
#  'Cincinnati, OH 45202\xa0(Central Business District area)',
#  'Cincinnati, OH 45202\xa0(Central Business District area)',
#  'Cincinnati, OH 45202\xa0(Central Business District area)',
#  'Cincinnati, OH 45202\xa0(Central Business District area)',
#  'Cincinnati, OH 45202\xa0(Central Business District area)',
#  'Cincinnati, OH 45202\xa0(Central Business District area)',
#  'Hybrid work in Cincinnati, OH',
#  'Hybrid work in Cincinnati, OH',
#  'Cincinnati, OH',
#  'Cincinnati, OH 45203\xa0(Central Business District area)',
#  'Cincinnati, OH 45202\xa0(Mount Adams area)',
#  'Cincinnati, OH 45237\xa0(Roselawn area)',
#  'Cincinnati, OH 45202\xa0(Central Business District area)']

# %%
salary
# Out:
# ['$45 - $55 an hour',
#  'Not Provided',
#  'Not Provided',
#  'Not Provided',
#  'Not Provided',
#  'Not Provided',
#  'Not Provided',
#  'Not Provided',
#  'Not Provided',
#  'Not Provided',
#  '$71,984 - $86,279 a year',
#  '$250,000 - $260,000 a year',
#  '$165,325 - $213,950 a year',
#  'Not Provided',
#  'Not Provided']

# %%
job_types
# Out:
# ['Full-time',
#  'Full-time',
#  'Full-time',
#  'Full-time',
#  'Full-time',
#  'Full-time',
#  'Full-time',
#  'Not Provided',
#  'Not Provided',
#  'Full-time',
#  'Not Provided',
#  'Full-time',
#  'Full-time',
#  'Not Provided',
#  'Full-time']

# %%
base_url = "https://www.indeed.com"
links = all_links  # assuming all_links is your list of job links
indeed_urls = []

for link in links:
    indeed_urls.append(base_url + link)

# %%
indeed_urls
# Out:
# ['https://www.indeed.com/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  'https://www.indeed.com/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  'https://www.indeed.com/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  'https://www.indeed.com/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
# ...

# %%
indeed_urls = indeed_urls[:len(location)]
indeed_urls
# Out:
# ['https://www.indeed.com/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  'https://www.indeed.com/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  'https://www.indeed.com/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
#  'https://www.indeed.com/rc/clk?jk=c1f7583df0a1a9df&bb=8Epcjg8V20naPD8ZWc-NPgEG2V0qWFAm4XKJmMLnjwNwMD7qJJJXPq4vo7J6lPvSV3NmBqR_Z07vfTFbGSwe3AzHMz5-QyIdgsnGRYjNnZINaUkLZWo00Q%3D%3D&xkcb=SoDS67M3-F5BP3wY6Z0YbzkdCdPP&fccid=a4e4e2eaf26690c9&vjs=3',
# ...

# %%
len(job_titles)
# Out:
# 15

# %%
len(company)
# Out:
# 15

# %%
len(location)
# Out:
# 15

# %%
len(salary)
# Out:
# 15

# %%
len(job_types)
# Out:
# 15

# %%
len(all_descriptions)
# Out:
# 15

# %%
len(indeed_urls)
# Out:
# 15

# %%
df = pd.DataFrame({
    'Job Title': job_titles,
    'Company': company,
    'Location': location,
    'Salary($)': salary,
    'Job-Type' : job_types,
    'Job-Description': all_descriptions,
    'Link': indeed_urls
})

# %%
print(df)
# Out:
#                                             Job Title  \
# 0   Senior Engineer - Generative AI Product Engine...
# 1                         AI Engineer - San Francisco
# 2                 Model Teacher, Technical (Contract)
# 3      Senior Creative Enterprise Developer Relations
# 4                                Staff Data Scientist
# 5   Head of AI Research and Development (100% remo...
# 6   Postdoctoral Researcher, Artificial Intelligen...
# 7         Program Manager, Service Quality Innovation
# 8                                   Sr Data Scientist
# 9   Public Policy and Government Relations Manager...
# 10                          Founding Product Designer
# 11              VP, Creative Cloud Enterprise Product
# 12  Senior Scientist, Artificial Intelligence/Mach...
# 13                                   Meetings Manager
# 14                    Principal AI Research Scientist
#
#                                   Company  \
# 0                             Capital One
# ...

# %%
from datetime import datetime

# %%
df['Scraped_On'] = datetime.today().strftime('%Y-%m-%d')
df
# Out:
#                                             Job Title  \
# 0   Senior Engineer - Generative AI Product Engine...
# 1                         AI Engineer - San Francisco
# 2                 Model Teacher, Technical (Contract)
# 3      Senior Creative Enterprise Developer Relations
# 4                                Staff Data Scientist
# 5   Head of AI Research and Development (100% remo...
# 6   Postdoctoral Researcher, Artificial Intelligen...
# 7         Program Manager, Service Quality Innovation
# 8                                   Sr Data Scientist
# 9   Public Policy and Government Relations Manager...
# 10                          Founding Product Designer
# 11              VP, Creative Cloud Enterprise Product
# 12  Senior Scientist, Artificial Intelligence/Mach...
# 13                                   Meetings Manager
# 14                    Principal AI Research Scientist
#
#                                   Company  \
# 0                             Capital One
# ...

# %%
df.to_csv("First-Page-AI-Cincinati.csv")
